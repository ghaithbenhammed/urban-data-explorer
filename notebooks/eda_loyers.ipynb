# %%
import pandas as pd

df = pd.read_csv("../data/bronze/loyers.csv", sep=";", encoding="latin1")
df.head()
# Out:
#   id_zone INSEE_C               LIBGEO       EPCI DEP  REG         loypredm2  \
# 0       1   52165            Dancevoir  245200597  52   44  6,29469619945702
# 1       1   21115               Buncey  242101434  21   27  6,29469619945702
# 2       1   21154  Châtillon-sur-Seine  242101434  21   27  7,61249180315074
# 3       1   52526    Villars-Santenoge  200027308  52   44  6,29469619945702
# 4       1   21519      Recey-sur-Ource  242101434  21   27  6,29469619945702
#
#            lwr.IPm2          upr.IPm2  TYPPRED  nbobs_com  nbobs_mail  \
# 0  4,82499769499072   8,2120661497093   maille         15         473
# 1  4,82499769499072   8,2120661497093   maille         24         473
# 2   5,8352077072778  9,93110003278216  commune        221         473
# 3  4,82499769499072   8,2120661497093   maille          3         473
# 4  4,82499769499072   8,2120661497093   maille         10         473
#
#               R2_adj
# 0  0,716929797607486
# 1  0,716929797607486
# 2  0,716929797607486
# 3  0,716929797607486
# 4  0,716929797607486

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34970 entries, 0 to 34969
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_zone     34970 non-null  object
#  1   INSEE_C     34970 non-null  object
#  2   LIBGEO      34970 non-null  object
#  3   EPCI        34970 non-null  object
#  4   DEP         34970 non-null  object
#  5   REG         34970 non-null  int64
#  6   loypredm2   34970 non-null  object
#  7   lwr.IPm2    34970 non-null  object
#  8   upr.IPm2    34970 non-null  object
#  9   TYPPRED     34970 non-null  object
#  10  nbobs_com   34970 non-null  int64
#  11  nbobs_mail  34970 non-null  int64
#  12  R2_adj      34970 non-null  object
# dtypes: int64(3), object(10)
# memory usage: 3.5+ MB

# %%
df.isnull().sum()
# Out:
# id_zone       0
# INSEE_C       0
# LIBGEO        0
# EPCI          0
# DEP           0
# REG           0
# loypredm2     0
# lwr.IPm2      0
# upr.IPm2      0
# TYPPRED       0
# nbobs_com     0
# nbobs_mail    0
# R2_adj        0
# dtype: int64

# %%
df.describe()
# Out:
#                 REG     nbobs_com    nbobs_mail
# count  34970.000000  34970.000000  34970.000000
# mean      52.300829     44.953617    628.680669
# std       24.344064    139.456290    316.844759
# min        1.000000      0.000000    466.000000
# 25%       28.000000      4.000000    482.000000
# 50%       44.000000     12.000000    510.000000
# 75%       76.000000     37.000000    652.000000
# max       94.000000   5464.000000   5950.000000

# %%
df["INSEE_C"].astype(str).str.startswith("75").sum()
# Out:
# 20

# %%
df["loypredm2"] = df["loypredm2"].astype(str)

df["loypredm2"] = df["loypredm2"].str.replace(",", ".")

df["loypredm2"] = pd.to_numeric(df["loypredm2"], errors="coerce")

# %%
df["loypredm2"].hist()
# Out:
# <Axes: >

# %%
df["INSEE_C"] = df["INSEE_C"].astype(str)

df_paris = df[df["INSEE_C"].str.startswith("75")]

print(df_paris.shape)
# Out:
# (20, 13)
