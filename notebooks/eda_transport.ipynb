# %%
import pandas as pd

df = pd.read_csv(
    "../data/bronze/arrets-lignes.csv",
    sep=None,
    engine="python",
    on_bad_lines="skip"
)
print(df.head())
print(df.info())
print(df.describe())
# Out:
#      ﻿route_id route_long_name     stop_id               stop_name  stop_lon  \
# 0  IDFM:C01389              T1  IDFM:23313  Théâtre Gérard Philipe  2.350469
# 1  IDFM:C01389              T1  IDFM:22268   Marché de Saint-Denis  2.355875
# 2  IDFM:C01389              T1  IDFM:24429         Stade Géo André  2.402069
# 3  IDFM:C01389              T1  IDFM:24427                  Danton  2.406619
# 4  IDFM:C01389              T1  IDFM:24424         Drancy - Avenir  2.417673
#
#     stop_lat OperatorName shortName bookingRules     mode  \
# 0  48.937500         RATP        T1          NaN  Tramway
# 1  48.938563         RATP        T1          NaN  Tramway
# 2  48.924333         RATP        T1          NaN  Tramway
# 3  48.922656         RATP        T1          NaN  Tramway
# 4  48.917746         RATP        T1          NaN  Tramway
#
#                                 Pointgeo   Nom_commune  Code_insee
# 0   48.93749994624904, 2.350468785750953   Saint-Denis       93066
# ...
